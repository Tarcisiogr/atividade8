# %% [markdown]
# <a href="https://colab.research.google.com/github/Tarcisiogr/atividade8/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
print(tf.__version__)

# !pip install -q tensorflow-datasets
# Out:
# 2.9.2

# %%
import tensorflow_datasets as tfds
imdb, info = tfds.load("ag_news_subset", with_info=True, as_supervised=True)
import numpy as np

train_data, test_data = imdb['train'], imdb['test']

training_sentences = []
training_labels = []

testing_sentences = []
testing_labels = []

# str(s.tonumpy()) is needed in Python3 instead of just s.numpy()
for s,l in train_data:
  training_sentences.append(str(s.numpy()))
  training_labels.append(l.numpy())
  
for s,l in test_data:
  testing_sentences.append(str(s.numpy()))
  testing_labels.append(l.numpy())
  
training_labels_final = np.array(training_labels)
testing_labels_final = np.array(testing_labels)
# Out:
# Downloading and preparing dataset 11.24 MiB (download: 11.24 MiB, generated: 35.79 MiB, total: 47.03 MiB) to ~/tensorflow_datasets/ag_news_subset/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/120000 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/ag_news_subset/1.0.0.incompleteJCCWT3/ag_news_subset-train.tfrecord*...:   0%|…
# Generating test examples...:   0%|          | 0/7600 [00:00<?, ? examples/s]
# Shuffling ~/tensorflow_datasets/ag_news_subset/1.0.0.incompleteJCCWT3/ag_news_subset-test.tfrecord*...:   0%| …
# Dataset ag_news_subset downloaded and prepared to ~/tensorflow_datasets/ag_news_subset/1.0.0. Subsequent calls will reuse this data.

# %%
vocab_size = 10000
embedding_dim = 16
max_length = 120
trunc_type='post'
oov_tok = ""


from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(training_sentences)
padded = pad_sequences(sequences,maxlen=max_length, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences,maxlen=max_length)
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

def decode_review(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])

print(decode_review(padded[1]))
print(training_sentences[1])
# Out:
# ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? b'reuters major league baseball monday announced a decision on the appeal filed by chicago cubs pitcher kerry wood regarding a suspension stemming from an incident earlier this season '
# b'Reuters - Major League Baseball\\Monday announced a decision on the appeal filed by Chicago Cubs\\pitcher Kerry Wood regarding a suspension stemming from an\\incident earlier this season.'

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.GRU(32)),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(4, activation='softmax')
])
#model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
num_epochs = 10
history = model.fit(padded, training_labels_final, epochs=num_epochs, validation_data=(testing_padded, testing_labels_final))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 120, 16)           160000
#
#  bidirectional (Bidirectiona  (None, 64)               9600
#  l)
#
#  dense (Dense)               (None, 6)                 390
#
#  dense_1 (Dense)             (None, 4)                 28
#
# =================================================================
# Total params: 170,018
# Trainable params: 170,018
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3750/3750 [==============================] - 227s 59ms/step - loss: 0.5337 - accuracy: 0.7809 - val_loss: 0.3315 - val_accuracy: 0.8874
# Epoch 2/10
# 3750/3750 [==============================] - 222s 59ms/step - loss: 0.2786 - accuracy: 0.9058 - val_loss: 0.2928 - val_accuracy: 0.9011
# Epoch 3/10
# 3750/3750 [==============================] - 232s 62ms/step - loss: 0.2299 - accuracy: 0.9233 - val_loss: 0.2877 - val_accuracy: 0.9046
# Epoch 4/10
# 3750/3750 [==============================] - 222s 59ms/step - loss: 0.2026 - accuracy: 0.9318 - val_loss: 0.2851 - val_accuracy: 0.9042
# Epoch 5/10
# 3750/3750 [==============================] - 220s 59ms/step - loss: 0.1803 - accuracy: 0.9387 - val_loss: 0.2943 - val_accuracy: 0.9013
# Epoch 6/10
# 3750/3750 [==============================] - 220s 59ms/step - loss: 0.1597 - accuracy: 0.9466 - val_loss: 0.3070 - val_accuracy: 0.9025
# Epoch 7/10
# 3750/3750 [==============================] - 220s 59ms/step - loss: 0.1409 - accuracy: 0.9526 - val_loss: 0.3364 - val_accuracy: 0.8982
# Epoch 8/10
# 3750/3750 [==============================] - 221s 59ms/step - loss: 0.1236 - accuracy: 0.9591 - val_loss: 0.3541 - val_accuracy: 0.8986
# Epoch 9/10
# 3750/3750 [==============================] - 220s 59ms/step - loss: 0.1085 - accuracy: 0.9645 - val_loss: 0.3757 - val_accuracy: 0.8941
# Epoch 10/10
# 3750/3750 [==============================] - 219s 59ms/step - loss: 0.0938 - accuracy: 0.9697 - val_loss: 0.3944 - val_accuracy: 0.8961

# %%
import matplotlib.pyplot as plt


def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')

# %%
# Model Definition with LSTM
model2 = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(4, activation='softmax')
])
model2.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model2.summary()
num_epochs = 10
history = model2.fit(padded, training_labels_final, epochs=num_epochs, validation_data=(testing_padded, testing_labels_final))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 120, 16)           160000
#
#  bidirectional_1 (Bidirectio  (None, 64)               12544
#  nal)
#
#  dense_2 (Dense)             (None, 6)                 390
#
#  dense_3 (Dense)             (None, 4)                 28
#
# =================================================================
# Total params: 172,962
# Trainable params: 172,962
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3750/3750 [==============================] - 238s 63ms/step - loss: 0.4530 - accuracy: 0.8353 - val_loss: 0.3238 - val_accuracy: 0.8939
# Epoch 2/10
# 3750/3750 [==============================] - 235s 63ms/step - loss: 0.2672 - accuracy: 0.9110 - val_loss: 0.3027 - val_accuracy: 0.8984
# Epoch 3/10
# 3750/3750 [==============================] - 238s 64ms/step - loss: 0.2241 - accuracy: 0.9242 - val_loss: 0.2938 - val_accuracy: 0.9021
# Epoch 4/10
# 3750/3750 [==============================] - 238s 64ms/step - loss: 0.1972 - accuracy: 0.9326 - val_loss: 0.2973 - val_accuracy: 0.9036
# Epoch 5/10
# 3750/3750 [==============================] - 241s 64ms/step - loss: 0.1732 - accuracy: 0.9399 - val_loss: 0.3177 - val_accuracy: 0.8976
# Epoch 6/10
# 3750/3750 [==============================] - 240s 64ms/step - loss: 0.1530 - accuracy: 0.9475 - val_loss: 0.3446 - val_accuracy: 0.8957
# Epoch 7/10
# 3750/3750 [==============================] - 241s 64ms/step - loss: 0.1349 - accuracy: 0.9537 - val_loss: 0.3633 - val_accuracy: 0.8962
# Epoch 8/10
# 3750/3750 [==============================] - 242s 64ms/step - loss: 0.1174 - accuracy: 0.9594 - val_loss: 0.4020 - val_accuracy: 0.8882
# Epoch 9/10
# 3750/3750 [==============================] - 240s 64ms/step - loss: 0.1024 - accuracy: 0.9645 - val_loss: 0.4060 - val_accuracy: 0.8874
# Epoch 10/10
# 3750/3750 [==============================] - 240s 64ms/step - loss: 0.0900 - accuracy: 0.9688 - val_loss: 0.4425 - val_accuracy: 0.8900

# %%
# Model Definition with Conv1D
model3 = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Conv1D(128, 5, activation='relu'),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(4, activation='softmax')
])
model3.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model3.summary()
num_epochs = 10
history = model3.fit(padded, training_labels_final, epochs=num_epochs, validation_data=(testing_padded, testing_labels_final))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 120, 16)           160000
#
#  conv1d (Conv1D)             (None, 116, 128)          10368
#
#  global_average_pooling1d (G  (None, 128)              0
#  lobalAveragePooling1D)
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_5 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 178,884
# Trainable params: 178,884
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 3750/3750 [==============================] - 54s 14ms/step - loss: 0.4316 - accuracy: 0.8514 - val_loss: 0.3140 - val_accuracy: 0.8933
# Epoch 2/10
# 3750/3750 [==============================] - 54s 14ms/step - loss: 0.2784 - accuracy: 0.9103 - val_loss: 0.2879 - val_accuracy: 0.9012
# Epoch 3/10
# 3750/3750 [==============================] - 54s 14ms/step - loss: 0.2400 - accuracy: 0.9209 - val_loss: 0.2885 - val_accuracy: 0.8995
# Epoch 4/10
# 3750/3750 [==============================] - 53s 14ms/step - loss: 0.2174 - accuracy: 0.9274 - val_loss: 0.2994 - val_accuracy: 0.9005
# Epoch 5/10
# 3750/3750 [==============================] - 55s 15ms/step - loss: 0.2005 - accuracy: 0.9319 - val_loss: 0.3017 - val_accuracy: 0.8995
# Epoch 6/10
# 3750/3750 [==============================] - 55s 15ms/step - loss: 0.1816 - accuracy: 0.9366 - val_loss: 0.3420 - val_accuracy: 0.8988
# Epoch 7/10
# 3750/3750 [==============================] - 54s 14ms/step - loss: 0.1657 - accuracy: 0.9401 - val_loss: 0.3418 - val_accuracy: 0.8978
# Epoch 8/10
# 3750/3750 [==============================] - 54s 14ms/step - loss: 0.1497 - accuracy: 0.9451 - val_loss: 0.3828 - val_accuracy: 0.8949
# Epoch 9/10
# 3750/3750 [==============================] - 54s 14ms/step - loss: 0.1362 - accuracy: 0.9485 - val_loss: 0.3931 - val_accuracy: 0.8945
# Epoch 10/10
# 3750/3750 [==============================] - 53s 14ms/step - loss: 0.1226 - accuracy: 0.9526 - val_loss: 0.4437 - val_accuracy: 0.8949
